# %% [markdown]
# ### Essential NumPy and Pandas Functions for Data Analysis
#
# Let's look at practical code snippets that demonstrate the most useful NumPy and pandas methods for data analysis in Python. You can use these in a Jupyter notebook for experimentation and workflow mastery.

# %% [markdown]
# #### NumPy Basics for Data Analysis
# Import NumPy:

# %%
import numpy as np

# %% [markdown]
# 1. Creating Arrays

# %%
arr = np.array([1, 2, 3, 4])            # 1D array
matrix = np.array([[1, 2], [3, 4]])     # 2D array
zeros = np.zeros((2, 3))                # 2x3 array of zeros
ones = np.ones((2, 3))                  # 2x3 array of ones
rnd = np.random.rand(2, 3)              # 2x3 array of random floats

# %% [markdown]
# 2. Array Shape, Reshape, Flatten

# %%
print(arr.shape)                # (4,)
reshaped = matrix.reshape((4, 1))   # Reshape to 4 rows, 1 column
flat = matrix.ravel()               # Flatten to 1D array
# Out:
# (4,)

# %% [markdown]
# 3. Indexing and Slicing

# %%
print(matrix[0, 1])    # element at first row, second column
print(arr[1:3])        # slice elements 1 to 2
# Out:
# 2
# [2 3]

# %% [markdown]
# 4. Basic Math Operations

# %%
a = np.array([10, 20, 30])
b = np.array([1, 2, 3])
print(a + b)           # [11 22 33]
print(a - b)           # [ 9 18 27]
print(a * b)           # [10 40 90]
print(a / b)           # [10. 10. 10.]
# Out:
# [11 22 33]
# [ 9 18 27]
# [10 40 90]
# [10. 10. 10.]

# %% [markdown]
# 5. Aggregation and Stats

# %%
np.sum(arr)                 # 10
np.mean(arr)                # 2.5
np.std(arr)                 # Standard deviation
np.min(arr), np.max(arr)    # Min and max values
# Out:
# (np.int64(1), np.int64(4))

# %% [markdown]
# 6. Dot Product, Matrix Ops

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
dot = np.dot(a, b)          # 1*4 + 2*5 + 3*6 = 32
mat = np.array([[1, 2], [3, 4]])
mat2 = np.array([[5, 6], [7, 8]])
matprod = np.matmul(mat, mat2) # Matrix multiplication

# %% [markdown]
# 7. Logical and Filtering

# %%
arr[arr > 2]                # Returns [3, 4]
np.where(arr > 2)           # Indices where condition is true
# Out:
# (array([2, 3]),)

# %% [markdown]
# 8. Random Sampling

# %%
np.random.randint(0, 100, size=5) # 5 random ints 0-99
np.random.choice([0, 1], size=10) # 10 random 0s or 1s
# Out:
# array([1, 0, 0, 1, 0, 0, 0, 1, 1, 0])

# %% [markdown]
# #### Pandas Basics for Data Analysis
# Import pandas:

# %%
import pandas as pd

# %% [markdown]
# 1. Creating DataFrames

# %%
data = {'A': [1, 2, 3], 'B': [4, 5, 6]}
df = pd.DataFrame(data) # Create DataFrame

# %% [markdown]
# 2. Inspecting Data

# %%
df.head()                # First 5 rows
df.tail(3)                # Last 3 rows
df.info()                 # DataFrame info + datatypes
df.describe()             # Summary statistics
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
# dtypes: int64(2)
# memory usage: 180.0 bytes
#          A    B
# count  3.0  3.0
# mean   2.0  5.0
# std    1.0  1.0
# min    1.0  4.0
# 25%    1.5  4.5
# 50%    2.0  5.0
# 75%    2.5  5.5
# max    3.0  6.0

# %% [markdown]
# 3. Selecting Data

# %%
df['A']                   # Get column A
df.loc[0]                 # Row by label (index 0)
df.iloc[1:3]              # Rows 1-2 by position
df[df['A'] > 1]           # Filter rows where A > 1
# Out:
#    A  B
# 1  2  5
# 2  3  6

# %% [markdown]
# 4. Adding/Dropping Columns

# %%
df['C'] = df['A'] + df['B']     # Add new column
new_df = df.drop('B', axis=1)   # Drop column B

# %% [markdown]
# 5. Missing Values & Types

# %%
df.isnull().sum()               # Missing values per column
df.fillna(0)                    # Replace NaNs with 0
df['A'] = df['A'].astype(float) # Change column type

# %% [markdown]
# 6. Grouping and Aggregation

# %%
grouped = df.groupby('A').sum()   # Sum columns, grouped by values in A
df['A'].value_counts()            # Count unique values in A
# Out:
# A
# 1.0    1
# 2.0    1
# 3.0    1
# Name: count, dtype: int64

# %% [markdown]
# 7. Sorting

# %%
df.sort_values('B', ascending=False)  # Sort by column B
# Out:
#      A  B  C
# 2  3.0  6  9
# 1  2.0  5  7
# 0  1.0  4  5

# %% [markdown]
# 8. Reading/Writing Files

# %%
df.to_csv('mydata.csv') # Save to CSV
df = pd.read_csv('mydata.csv') # Load from CSV
df.head()
# Out:
#    Unnamed: 0    A  B  C
# 0           0  1.0  4  5
# 1           1  2.0  5  7
# 2           2  3.0  6  9

# %% [markdown]
# 9. Apply/Map Functions

# %%
df['A_squared'] = df['A'].apply(lambda x: x**2) # Apply to column
df['B_label'] = df['B'].map({4: 'Low', 5: 'Med', 6: 'High'}) # Map values
df.sample(3)
# Out:
#    Unnamed: 0    A  B  C  A_squared B_label
# 1           1  2.0  5  7        4.0     Med
# 2           2  3.0  6  9        9.0    High
# 0           0  1.0  4  5        1.0     Low

# %% [markdown]
# ### Task:

# %% [markdown]
# - Generated a Synthetic Dataset with columns of `age`, `salary`, `department`, `years_experience`, and `is_manager`.

# %%
np.random.seed(42) # For reproducibility
n_samples = 100 # Number of samples

data = {
    'age': np.random.randint(18, 60, size=n_samples),
    'salary': np.random.randint(30000, 120000, size=n_samples),
    'department': np.random.choice(['IT', 'HR', 'Finance', 'Marketing'], size=n_samples),
    'years_experience': np.round(np.random.normal(5, 2, size=n_samples), 1),
    'is_manager': np.random.choice([0, 1], size=n_samples)
}
df = pd.DataFrame(data)

# %% [markdown]
# Q1. View data structure

# %%
from IPython.display import display
print("Shape:", df.shape)
display(df.head())
# Out:
# Shape: (100, 5)
#    age  salary department  years_experience  is_manager
# 0   56   38392         IT              -0.8           0
# 1   46   60535  Marketing               3.4           1
# 2   32  108603         HR               5.0           1
# 3   25   82256         HR               4.2           1
# 4   38  119135         HR               4.1           1

# %% [markdown]
# Q2. Get DataFrame Info and Summary Stats

# %%
df.info()
display(df.describe(include='all').transpose())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               100 non-null    int64
#  1   salary            100 non-null    int64
#  2   department        100 non-null    object
#  3   years_experience  100 non-null    float64
#  4   is_manager        100 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 4.0+ KB
#                   count unique        top freq      mean           std  \
# age               100.0    NaN        NaN  NaN     37.91     12.219454
# salary            100.0    NaN        NaN  NaN  77809.16  26058.643576
# department          100      4  Marketing   36       NaN           NaN
# years_experience  100.0    NaN        NaN  NaN     4.823      2.237822
# is_manager        100.0    NaN        NaN  NaN      0.47      0.501614
#
#                       min      25%      50%       75%       max
# age                  18.0    26.75     38.0     46.25      59.0
# salary            30206.0  55141.0  80932.0  98107.25  119474.0
# department            NaN      NaN      NaN       NaN       NaN
# years_experience     -0.8    3.475      4.7       6.0      11.4
# is_manager            0.0      0.0      0.0       1.0       1.0

# %% [markdown]
# Q3. Do Simple Numpy Operations

# %%
# basic numpy ops and using dataframe column as numpy array
arr = np.array([1, 2, 3, 4])
print("array:", arr)
print("sum:", arr.sum(), "mean:", arr.mean(), "std:", arr.std())

salaries = df['salary'].to_numpy()
print("Salary stats -> mean:", salaries.mean(), "min:", salaries.min(), "max:", salaries.max())
# Out:
# array: [1 2 3 4]
# sum: 10 mean: 2.5 std: 1.118033988749895
# Salary stats -> mean: 77809.16 min: 30206 max: 119474

# %% [markdown]
# Q4. Filtering and Indexing Rows

# %%
over_30 = df[df['age'] > 30]
managers = df[df['is_manager'] == 1]
it_dept = df[df['department'] == 'IT']

print("Count age > 30:", len(over_30))
display(over_30.head())
print("Managers sample:")
display(managers.head())
print("IT department sample:")
display(it_dept.head())

print("Row by loc (index 0):")
display(df.loc[0])
print("Rows by iloc (1:4):")
display(df.iloc[1:4])
# Out:
# Count age > 30: 70
#    age  salary department  years_experience  is_manager
# 0   56   38392         IT              -0.8           0
# 1   46   60535  Marketing               3.4           1
# 2   32  108603         HR               5.0           1
# 4   38  119135         HR               4.1           1
# 5   56   65222    Finance               2.8           0
# Managers sample:
#    age  salary department  years_experience  is_manager
# 1   46   60535  Marketing               3.4           1
# 2   32  108603         HR               5.0           1
# 3   25   82256         HR               4.2           1
# 4   38  119135         HR               4.1           1
# 6   36  107373    Finance               6.7           1
# IT department sample:
#     age  salary department  years_experience  is_manager
# 0    56   38392         IT              -0.8           0
# 9    28   93335         IT               1.2           1
# 10   41   40965         IT               9.5           1
# 15   39   57266         IT               5.8           1
# 30   32   86044         IT               4.7           0
# Row by loc (index 0):
# age                    56
# salary              38392
# department             IT
# years_experience     -0.8
# is_manager              0
# Name: 0, dtype: object
# Rows by iloc (1:4):
#    age  salary department  years_experience  is_manager
# 1   46   60535  Marketing               3.4           1
# 2   32  108603         HR               5.0           1
# 3   25   82256         HR               4.2           1

# %% [markdown]
# Q5. Adding a Column

# %%
df['salary_k'] = (df['salary'] / 1000).round(1)             # salary in thousands
df['seniority'] = pd.cut(df['years_experience'],
                         bins=[-1, 2, 5, 10, 100],
                         labels=['Junior', 'Mid', 'Senior', 'Lead'])
display(df.head())
# Out:
#    age  salary department  years_experience  is_manager  salary_k seniority
# 0   56   38392         IT              -0.8           0      38.4    Junior
# 1   46   60535  Marketing               3.4           1      60.5       Mid
# 2   32  108603         HR               5.0           1     108.6       Mid
# 3   25   82256         HR               4.2           1      82.3       Mid
# 4   38  119135         HR               4.1           1     119.1       Mid

# %% [markdown]
# Q6. Grouping and Aggregation

# %%
dept_stats = df.groupby('department').agg(
    count=('age', 'size'),
    avg_salary=('salary', 'mean'),
    avg_experience=('years_experience', 'mean'),
    managers=('is_manager', 'sum')
).reset_index()
display(dept_stats)

print("Manager counts per department:")
display(df.groupby('department')['is_manager'].sum())
# Out:
#   department  count    avg_salary  avg_experience  managers
# 0    Finance     24  83124.708333        4.416667        10
# 1         HR     19  73523.052632        5.089474        10
# 2         IT     21  75825.476190        4.390476        13
# 3  Marketing     36  77684.722222        5.205556        14
# Manager counts per department:
# department
# Finance      10
# HR           10
# IT           13
# Marketing    14
# Name: is_manager, dtype: int64
